# %%
import pandas as pd
import numpy as np
import os
from sklearn.base import BaseEstimator, TransformerMixin
import seaborn as sns

# %%
os.chdir('/Users/matthewlafferty/Dropbox/GitHub/tab_apr_2021')

# %%
data_path = '/Users/matthewlafferty/Dropbox/Kaggle/Tabular_Apr_2021/tabular-playground-series-apr-2021'

# %% [markdown]
# ----
# # EDA

# %%
data = pd.read_csv(data_path + '/train.csv')

# %%
data.sample(10)
# Out:
#        PassengerId  Survived  Pclass              Name     Sex   Age  SibSp  \
# 57056        57056         1       3      Tarr, Miguel    male  15.0      0
# 82735        82735         0       2     Bevins, Karen  female  63.0      2
# 33305        33305         0       3  Bennett, Richard    male  23.0      0
# 60770        60770         0       1  Voegele, Stephen    male  47.0      0
# 48633        48633         1       2     Delmoro, Mary  female   2.0      1
# 55092        55092         0       1       Roy, Sharon  female  57.0      0
# 65443        65443         0       1      Uber, Harvey    male  54.0      1
# 69299        69299         0       2    Carovski, Paul    male  18.0      0
# 64396        64396         1       2  Crawford, Millie  female  48.0      0
# 11587        11587         0       3     Mcclain, Mary  female   7.0      1
#
#        Parch      Ticket    Fare   Cabin Embarked
# 57056      0         NaN   11.83     NaN        S
# ...

# %% [markdown]
# ## Pclass

# %%
data.groupby(['Pclass'])['Survived'].agg(['sum','count','mean'])
# Out:
#           sum  count      mean
# Pclass
# 1       17576  30315  0.579779
# 2       15057  28679  0.525018
# 3       10141  41006  0.247305

# %% [markdown]
# `Pclass` could almost be left as is, since large values indicate greater risk of death. Were this not the case (and perhaps we will anyway) we could provide this as a categorical variable to lightGBM.

# %% [markdown]
# ## Name

# %%
data.reset_index(inplace=True)

# %%
data['name_split'] = data['Name'].str.split(',')

# %%
sum(data['name_split'].apply(lambda x:len(x)) == 2) / data.shape[0]
# Out:
# 1.0

# %%
data.sample(10)
# Out:
#        index  PassengerId  Survived  Pclass              Name     Sex   Age  \
# 32411  32411        32411         1       2   Dipaolo, George    male  32.0
# 75625  75625        75625         0       2      Shook, Ralph    male   1.0
# 81879  81879        81879         0       3    Gatlin, Wesley    male  50.0
# 42467  42467        42467         1       2   Jackson, Ronald    male  62.0
# 36470  36470        36470         1       2     Grisham, Edna  female  36.0
# 27647  27647        27647         1       3        Lee, Simon    male  25.0
# 95711  95711        95711         0       2     Huang, Joseph    male  32.0
# 9969    9969         9969         1       1  Riehle, Kimberly  female  41.0
# 19213  19213        19213         1       2       Moss, Nancy  female  57.0
# 16467  16467        16467         0       3      Guidry, Fred    male  44.0
#
#        SibSp  Parch    Ticket   Fare  Cabin Embarked           name_split
# ...

# %%
data[data['name_split'].apply(lambda x:x[0]) == 'Moss']
# Out:
#        index  PassengerId  Survived  Pclass            Name     Sex    Age  \
# 11142  11142        11142         0       1      Moss, Rose  female  52.00
# 14226  14226        14226         1       1  Moss, Jennifer  female  52.00
# 19213  19213        19213         1       2     Moss, Nancy  female  57.00
# 19384  19384        19384         0       2    Moss, Stacie  female  25.00
# 21935  21935        21935         1       3  Moss, Jennifer  female  16.00
# 22354  22354        22354         1       3  Moss, Laurence    male  59.00
# 22588  22588        22588         0       3   Moss, Roberta  female   5.00
# 25011  25011        25011         0       1    Moss, Marvin    male  42.00
# 25954  25954        25954         1       3       Moss, Ann  female  13.00
# 31784  31784        31784         0       3     Moss, Benny    male  22.00
# 33046  33046        33046         1       2    Moss, Meagan  female  51.00
# ...

# %%
I had hoped that perhaps with the name
